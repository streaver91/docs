# %%
pwd
# Out:
# u'/home/junhao/docs/kim/vacancypaper/relation'

# %%
ls
# Out:
# analysis.ipynb  analysis.xlsx  cleaned_data.csv  data.csv  getData.node.js

# %%
ls
# Out:
# analysis.ipynb  analysis.xlsx  cleaned_data.csv  data.csv  getData.node.js

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2885: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data = pd.read_csv('data.csv')

# %%
data['ln_neg_spdst33'] = np.log(-1.0 * data['spdst33'])

# %%
has_ln = data.columns.str.contains('ln_')
ln_cols = data.columns[has_ln]
ori_cols = data.columns[~has_ln]

# %%
data[ln_cols].describe(percentiles=[0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95])
# Out:
#             ln_a  ln_cohesive-energy     ln_c11     ln_c12    ln_bulk  \
# count  83.000000           83.000000  83.000000  83.000000  83.000000
# mean    1.361768            1.290157   0.273087  -0.515505  -0.068474
# std     0.095167            0.347463   1.212585   0.516795   1.008855
# min     1.179782            0.416487  -1.314231  -1.855095  -1.431212
# 5%      1.257927            0.576485  -0.636958  -1.458448  -0.962502
# 10%     1.258461            0.761038  -0.576607  -1.175171  -0.770660
# 25%     1.285086            1.199812  -0.342185  -0.947700  -0.696357
# 50%     1.394023            1.264127   0.052960  -0.534584  -0.154656
# 75%     1.408539            1.492904   0.431449  -0.083454   0.121872
# 90%     1.507464            1.718490   1.365057   0.000669   0.734773
# 95%     1.513923            1.862339   3.520232   0.224166   2.466094
# max     1.599257            2.151407   4.690750   0.678396   3.595006
#
#         ln_shear  ln_volume  ln_bulk*volume  ln_shear*volume  \
# count  83.000000  83.000000       83.000000        83.000000
# mean   -1.425128   4.085304        4.016830         2.660176
# std     1.555786   0.285500        0.987217         1.534827
# min    -3.805578   3.539347        2.928503         0.968323
# 5%     -2.774607   3.773781        3.124351         1.412765
# 10%    -2.487344   3.775383        3.347028         1.686813
# 25%    -2.236148   3.855259        3.489276         1.941610
# 50%    -1.837868   4.182070        3.793448         2.308831
# 75%    -1.236581   4.225616        3.937497         2.604941
# 90%     0.119449   4.522391        4.814874         4.100835
# 95%     2.803995   4.541769        6.358349         6.696249
# max     3.996166   4.797772        8.120700         8.521860
#
#        ln_formation-energy  ln_migration-energy  ln_relaxation-volume  \
# count            83.000000            83.000000             83.000000
# mean              0.148810            -0.361662            -13.396712
# std               0.472077             0.462278             35.827131
# min              -1.181731            -1.715494           -100.000000
# 5%               -0.518450            -1.196852           -100.000000
# 10%              -0.414584            -0.849235           -100.000000
# 25%              -0.158745            -0.528409              0.508373
# 50%               0.203054            -0.372735              1.261620
# 75%               0.467379            -0.044283              1.572329
# 90%               0.616668             0.032928              1.923493
# 95%               0.806134             0.246422              2.089891
# max               1.362464             1.037888              3.248130
#
#          ln_edt11  ln_spedt11  ln_spedt33  ln_spdst11  ln_spdst33  \
# count   83.000000   83.000000   83.000000   83.000000   83.000000
# mean   -13.670580   -9.834592  -82.922493  -14.076915  -93.756230
# std     35.713088   31.643528   38.149354   37.256562   24.810845
# min   -100.000000 -100.000000 -100.000000 -100.000000 -100.000000
# 5%    -100.000000 -100.000000 -100.000000 -100.000000 -100.000000
#
# min   -265.489233 -12.848347 -34.904820
# 5%     -57.757099  -3.899011 -23.974662
# 10%     -7.567075  -1.566731 -21.518622
# 25%     -4.495624   3.751327 -12.947092
# 50%     -1.856911   6.325425  -9.326473
# 75%     -1.011559   8.126846  -6.839222
# 90%      3.212374  12.807211  -1.484307
# 95%     12.840417  16.055937  27.882131
# max     16.183380  19.928807  40.448951

# %%
bad_cohesive_energy = data['cohesive-energy'] > 6.5
bad_bulk = data['bulk'] > 10
bad_shear = data['shear'] > 17

# %%
bad_formation_energy = data['formation-energy'] > 10
bad_migration_energy = data['migration-energy'] > 10
bad_relaxation_volume = (data['relaxation-volume'] < 0) | (data['relaxation-volume'] > 10)

# %%
bad_data = bad_cohesive_energy | bad_bulk | bad_shear | bad_formation_energy | bad_migration_energy | bad_relaxation_volume

# %%
cleaned_data = data[~bad_data]

# %%
cleaned_data
# Out:
#    elem                                              model         a  \
# 0    Ag   EAM_Dynamo_Ackland_Tichy_Ag__MO_212700056563_001  4.086000
# 1    Ag  EAM_Dynamo_Hale_Wong_pairHybrid_PdAgH__MO_1048...  4.089974
# 2    Ag  EAM_Dynamo_Hale_Wong_pairMorse_PdAgH__MO_10898...  4.089974
# 3    Ag  EAM_Dynamo_Williams_Mishin_Ag__MO_131620013077...  4.090000
# 4    Ag  EAM_Dynamo_Williams_Mishin_CuAg__MO_1287034835...  4.090000
# 5    Ag    EAM_Dynamo_Wu_Trinkle_CuAg__MO_270337113239_001  4.090069
# 7    Al  EAM_Dynamo_Angelo_Moody_NiAlH__MO_418978237058...  4.050000
# 8    Al        EAM_Dynamo_Cai_Ye_AlCu__MO_942551040047_001  4.049764
# 9    Al  EAM_Dynamo_Ercolessi_Adams_Al__MO_123629422045...  4.032082
# 10   Al  EAM_Dynamo_Landa_Wynblatt_AlPb__MO_69913739638...  4.031036
# 11   Al  EAM_Dynamo_Mendelev_Asta_AlMg__MO_658278549784...  4.045271
# 12   Al  EAM_Dynamo_Mendelev_Kramer_Al__MO_106969701023...  4.045260
# 13   Al  EAM_Dynamo_Mendelev_Srolovitz_AlFe__MO_5774538...  4.033302
# 14   Al   EAM_Dynamo_Mishin_Farkas_Al__MO_651801486679_001  4.050005
# 15   Al   EAM_Dynamo_Mishin_Mehl_NiAl__MO_109933561507_001  4.051526
# 16   Al        EAM_Dynamo_Mishin_NiAl__MO_101214310689_001  4.050000
# 17   Al  EAM_Dynamo_PurjaPun_Mishin_NiAl__MO_7513544037...  4.050000
# 18   Al  EAM_Dynamo_Sturgeon_Laird_Al__MO_120808805541_001  4.050010
# 19   Al  EAM_Dynamo_Vailhe_Farkas_CoAl__MO_284963179498...  4.049697
# 20   Al    EAM_Dynamo_Winey_Kubota_Al__MO_149316865608_001  4.024845
# 22   Al     EAM_Dynamo_Zope_Mishin_Al__MO_664470114311_001  4.050000
# 23   Al   EAM_Dynamo_Zope_Mishin_TiAl__MO_117656786760_001  4.049999
# 24   Au   EAM_Dynamo_Ackland_Tichy_Au__MO_104891429740_001  4.078000
# 26   Co  EAM_Dynamo_PurjaPun_Mishin_Co__MO_885079680379...  3.564222
# 27   Co  EAM_Dynamo_Vailhe_Farkas_CoAl__MO_284963179498...  3.542267
# 28   Co    EAM_Dynamo_Zhou_Johnson_Co__MO_924630542818_001  3.549098
# 29   Cu   EAM_Dynamo_Ackland_Tichy_Cu__MO_179025990738_001  3.615000
# 30   Cu  EAM_Dynamo_Bonny_Pasianot_FeCuNi__MO_469343973...  3.614925
# 31   Cu        EAM_Dynamo_Cai_Ye_AlCu__MO_942551040047_001  3.614728
# 32   Cu   EAM_Dynamo_Hoyt_Garvin_PbCu__MO_119135752160_001  3.615034
# ..  ...                                                ...       ...
# 38   Cu  EAM_Dynamo_Onat_Durukanoglu_CuNi__MO_592013496...  3.615002
# 39   Cu  EAM_Dynamo_Williams_Mishin_CuAg__MO_1287034835...  3.615000
# 40   Cu    EAM_Dynamo_Wu_Trinkle_CuAg__MO_270337113239_001  3.492128
# 42   Fe   EAM_Dynamo_Ackland_Bacon_Fe__MO_142799717516_001  3.680045
# 43   Fe  EAM_Dynamo_Ackland_Mendelev_FeP__MO_8843431463...  3.658405
# 44   Fe  EAM_Dynamo_Hepburn_Ackland_FeC__MO_14397715272...  3.658404
# 45   Fe  EAM_Dynamo_Mendelev_Han_Fe_5__MO_942420706858_001  3.658296
# 46   Fe   EAM_Dynamo_Mendelev_Han_VFe__MO_249706810527_001  3.658405
# 47   Fe  EAM_Dynamo_Mendelev_Srolovitz_AlFe__MO_5774538...  3.658403
# 48    H  EAM_Dynamo_Hale_Wong_pairHybrid_PdAgH__MO_1048...  3.253666
# 49    H  EAM_Dynamo_Hale_Wong_pairMorse_PdAgH__MO_10898...  3.253666
# 54   Ni   EAM_Dynamo_Ackland_Tichy_Ni__MO_977363131043_001  3.524220
# 55   Ni  EAM_Dynamo_Angelo_Moody_NiAlH__MO_418978237058...  3.520000
# 56   Ni  EAM_Dynamo_Bonny_Pasianot_FeCuNi__MO_469343973...  3.520001
# 57   Ni  EAM_Dynamo_Bonny_Pasianot_FeNi__MO_26772140893...  3.520001
# 60   Ni   EAM_Dynamo_Mishin_Farkas_Ni__MO_400591584784_001  3.519999
# 61   Ni   EAM_Dynamo_Mishin_Mehl_NiAl__MO_109933561507_001  3.452464
# 62   Ni        EAM_Dynamo_Mishin_NiAl__MO_101214310689_001  3.520000
# 63   Ni  EAM_Dynamo_Onat_Durukanoglu_CuNi__MO_592013496...  3.520000
# 64   Ni  EAM_Dynamo_PurjaPun_Mishin_NiAl__MO_7513544037...  3.520000
# 66    P  EAM_Dynamo_Ackland_Mendelev_FeP__MO_8843431463...  4.698099
# 70   Pd  EAM_Dynamo_Hale_Wong_pairHybrid_PdAgH__MO_1048...  3.884859
# 71   Pd  EAM_Dynamo_Hale_Wong_pairMorse_PdAgH__MO_10898...  3.884859
# 75   Ti         EAM_Dynamo_Ackland_Ti__MO_748534961139_001  4.172638
# 76   Ti    EAM_Dynamo_Zhou_Johnson_Ti__MO_723456820410_001  4.154817
# volume            -0.497284  1.000000    -0.011698     -0.244400
# bulk*volume        0.547833 -0.011698     1.000000      0.573266
# shear*volume       0.941709 -0.244400     0.573266      1.000000
# formation-energy  -0.069413  0.024452     0.101006     -0.095223
# migration-energy   0.278881 -0.107324     0.407396      0.289157
# relaxation-volume -0.267182  0.230772    -0.165586     -0.164797
# edt11              0.259624 -0.110528     0.580779      0.275632
# spedt11            0.028894  0.171118     0.473568      0.101242
# spedt33           -0.222743  0.098440    -0.241216     -0.226310
# spdst11           -0.207083  0.412224     0.334834     -0.124055
# spdst33            0.085151 -0.273443    -0.351173      0.025409
#
#                    formation-energy  migration-energy  relaxation-volume  \
# a                         -0.020777         -0.136511           0.292204
# cohesive-energy            0.698703          0.403177          -0.422964
# c11                        0.009076          0.376618          -0.307879
# c12                        0.080729          0.412722          -0.300946
# bulk                       0.047783          0.402771          -0.309652
# shear                     -0.069413          0.278881          -0.267182
# volume                     0.024452         -0.107324           0.230772
# bulk*volume                0.101006          0.407396          -0.165586
# shear*volume              -0.095223          0.289157          -0.164797
# formation-energy           1.000000          0.410103          -0.647702
# migration-energy           0.410103          1.000000          -0.567667
# relaxation-volume         -0.647702         -0.567667           1.000000
# edt11                     -0.392039         -0.197612           0.616203
# spedt11                    0.215909          0.065538           0.154526
# spedt33                    0.201267         -0.412716           0.255141
# spdst11                   -0.139156          0.218986           0.049136
# spdst33                    0.211329         -0.277370           0.017458
#
#                       edt11   spedt11   spedt33   spdst11   spdst33
# a                 -0.080502  0.170400  0.107921  0.409374 -0.270504
# cohesive-energy   -0.189362  0.419586  0.177232 -0.009028  0.106025
# c11                0.421820  0.191374 -0.268921 -0.049383 -0.060205
# c12                0.511281  0.314608 -0.272750  0.104416 -0.186592
# bulk               0.477484  0.261087 -0.275787  0.032470 -0.129270
# shear              0.259624  0.028894 -0.222743 -0.207083  0.085151
# volume            -0.110528  0.171118  0.098440  0.412224 -0.273443
# bulk*volume        0.580779  0.473568 -0.241216  0.334834 -0.351173
# shear*volume       0.275632  0.101242 -0.226310 -0.124055  0.025409
# formation-energy  -0.392039  0.215909  0.201267 -0.139156  0.211329
# migration-energy  -0.197612  0.065538 -0.412716  0.218986 -0.277370
# relaxation-volume  0.616203  0.154526  0.255141  0.049136  0.017458
# edt11              1.000000  0.462100  0.125051  0.102441 -0.086967
# spedt11            0.462100  1.000000  0.278864  0.287874 -0.105237
# spedt33            0.125051  0.278864  1.000000 -0.656048  0.813914
# spdst11            0.102441  0.287874 -0.656048  1.000000 -0.966098
# spdst33           -0.086967 -0.105237  0.813914 -0.966098  1.000000

# %%
cleaned_data[ln_cols].corr()
# Out:
#                           ln_a  ln_cohesive-energy    ln_c11    ln_c12  \
# ln_a                  1.000000            0.149745 -0.664366 -0.566719
# ln_cohesive-energy    0.149745            1.000000  0.058024  0.080692
# ln_c11               -0.664366            0.058024  1.000000  0.930125
# ln_c12               -0.566719            0.080692  0.930125  1.000000
# ln_bulk              -0.618312            0.068794  0.977203  0.986859
# ln_shear             -0.649817            0.064368  0.820325  0.557449
# ln_volume             1.000000            0.149745 -0.664366 -0.566719
# ln_bulk*volume       -0.006566            0.204352  0.725042  0.813506
# ln_shear*volume      -0.240166            0.170516  0.655860  0.377720
# ln_formation-energy  -0.122982            0.541921  0.137918  0.229301
# ln_migration-energy  -0.111971            0.363272  0.434327  0.454129
# ln_relaxation-volume  0.190242           -0.309822 -0.317999 -0.298501
# ln_edt11             -0.165383           -0.274408  0.243794  0.269168
# ln_spedt11           -0.067301            0.067158  0.014691  0.073292
# ln_spedt33           -0.085373            0.213527 -0.058847 -0.070730
# ln_spdst11            0.031907           -0.176883  0.371500  0.404615
# ln_spdst33           -0.020900            0.179395 -0.381976 -0.410128
# ln_neg_spdst33        0.543869            0.043723 -0.570539 -0.270943
#
#                        ln_bulk  ln_shear  ln_volume  ln_bulk*volume  \
# ln_a                 -0.618312 -0.649817   1.000000       -0.006566
# ln_cohesive-energy    0.068794  0.064368   0.149745        0.204352
# ln_c11                0.977203  0.820325  -0.664366        0.725042
# ln_c12                0.986859  0.557449  -0.566719        0.813506
# ln_bulk               1.000000  0.682175  -0.618312        0.789975
# ln_shear              0.682175  1.000000  -0.649817        0.361014
# ln_volume            -0.618312 -0.649817   1.000000       -0.006566
# ln_bulk*volume        0.789975  0.361014  -0.006566        1.000000
# ln_shear*volume       0.506585  0.893908  -0.240166        0.457188
# ln_formation-energy   0.189567  0.023902  -0.122982        0.145252
# ln_migration-energy   0.451028  0.325691  -0.111971        0.486511
# ln_relaxation-volume -0.310328 -0.297225   0.190242       -0.246429
# ln_edt11              0.264788  0.093874  -0.165383        0.207880
# ln_spedt11            0.048515 -0.071712  -0.067301        0.009224
# ln_spedt33           -0.066445 -0.035411  -0.085373       -0.151144
# ln_spdst11            0.398119  0.200612   0.031907        0.531438
# ln_spdst33           -0.405914 -0.215631  -0.020900       -0.532769
# ln_neg_spdst33       -0.410657 -0.820749   0.543869       -0.088581
#
#                       ln_shear*volume  ln_formation-energy  \
# ln_a                        -0.240166            -0.122982
# ln_cohesive-energy           0.170516             0.541921
# ln_c11                       0.655860             0.137918
# ln_c12                       0.377720             0.229301
# ln_bulk                      0.506585             0.189567
# ln_shear                     0.893908             0.023902
# ln_volume                   -0.240166            -0.122982
# ln_bulk*volume               0.457188             0.145252
# ln_shear*volume              1.000000            -0.042000
# ln_formation-energy         -0.042000             1.000000
# ln_migration-energy          0.349916             0.430684
# ln_relaxation-volume        -0.267401            -0.556485
# ln_edt11                     0.022358            -0.454622
# ln_spedt11                  -0.131275            -0.020067
# ln_spedt33                  -0.095571             0.230904
# ln_spdst11                   0.275024            -0.323546
# ln_spdst33                  -0.287714             0.326757
# ln_neg_spdst33              -0.749226             0.301602
#
#                       ln_migration-energy  ln_relaxation-volume  ln_edt11  \
# ln_a                            -0.111971              0.190242 -0.165383
# ln_cohesive-energy               0.363272             -0.309822 -0.274408
# ln_c11                           0.434327             -0.317999  0.243794
# ln_c12                           0.454129             -0.298501  0.269168
# ln_bulk                          0.451028             -0.310328  0.264788
# ln_shear                         0.325691             -0.297225  0.093874
# ln_volume                       -0.111971              0.190242 -0.165383
# ln_bulk*volume                   0.486511             -0.246429  0.207880
# ln_shear*volume                  0.349916             -0.267401  0.022358
# ln_formation-energy              0.430684             -0.556485 -0.454622
# ln_migration-energy              1.000000             -0.471225 -0.216598
# ln_relaxation-volume            -0.471225              1.000000  0.834528
# ln_edt11                        -0.216598              0.834528  1.000000
# ln_spedt11                      -0.067561              0.584056  0.620577
# ln_spedt33                      -0.266560              0.146344  0.109939
# ln_spdst11                       0.283392             -0.031234  0.199059
# ln_spdst33                      -0.283681              0.034645 -0.200116
# ln_neg_spdst33                   0.059400             -0.071240 -0.294587
#
#                       ln_spedt11  ln_spedt33  ln_spdst11  ln_spdst33  \
# ln_a                   -0.067301   -0.085373    0.031907   -0.020900
# ln_cohesive-energy      0.067158    0.213527   -0.176883    0.179395
# ln_c11                  0.014691   -0.058847    0.371500   -0.381976
# ln_c12                  0.073292   -0.070730    0.404615   -0.410128
# ln_bulk                 0.048515   -0.066445    0.398119   -0.405914
# ln_shear               -0.071712   -0.035411    0.200612   -0.215631
# ln_volume              -0.067301   -0.085373    0.031907   -0.020900
# ln_bulk*volume          0.009224   -0.151144    0.531438   -0.532769
# ln_shear*volume        -0.131275   -0.095571    0.275024   -0.287714
# ln_formation-energy    -0.020067    0.230904   -0.323546    0.326757
# ln_migration-energy    -0.067561   -0.266560    0.283392   -0.283681
# ln_relaxation-volume    0.584056    0.146344   -0.031234    0.034645
# ln_edt11                0.620577    0.109939    0.199059   -0.200116
# ln_spedt11              1.000000    0.059335   -0.028600    0.031349
# ln_spedt33              0.059335    1.000000   -0.730553    0.729009
# ln_spdst11             -0.028600   -0.730553    1.000000   -0.999836
# ln_spdst33              0.031349    0.729009   -0.999836    1.000000
# ln_neg_spdst33         -0.032842   -0.359807    0.908634         NaN
#
#                       ln_neg_spdst33
# ln_a                        0.543869
# ln_cohesive-energy          0.043723
# ln_c11                     -0.570539
# ln_c12                     -0.270943
# ln_bulk                    -0.410657
# ln_shear                   -0.820749
# ln_volume                   0.543869
# ln_bulk*volume             -0.088581
# ln_shear*volume            -0.749226
# ln_formation-energy         0.301602
# ln_migration-energy         0.059400
# ln_relaxation-volume       -0.071240
# ln_edt11                   -0.294587
# ln_spedt11                 -0.032842
# ln_spedt33                 -0.359807
# ln_spdst11                  0.908634
# ln_spdst33                       NaN
# ln_neg_spdst33              1.000000

# %%
import statsmodels.formula.api as sm

# %%
from pandas.stats.api import ols

# %%
ols(y=cleaned_data['formation-energy'], x=cleaned_data[['cohesive-energy']])
ols(y=cleaned_data['ln_formation-energy'], x=cleaned_data[['ln_a', 'ln_bulk']])
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2885: FutureWarning: The pandas.stats.ols module is deprecated and will be removed in a future version. We refer to external packages like statsmodels, see some examples here: http://statsmodels.sourceforge.net/stable/regression.html
#   exec(code_obj, self.user_global_ns, self.user_ns)
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <ln_a> + <ln_bulk> + <intercept>
#
# Number of Observations:         65
# Number of Degrees of Freedom:   3
#
# R-squared:         0.0360
# Adj R-squared:     0.0049
#
# Rmse:              0.3787
#
# F-stat (2, 62):     1.1573, p-value:     0.3210
#
# Degrees of Freedom: model 2, resid 62
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#           ln_a    -0.0424     0.7203      -0.06     0.9532    -1.4541     1.3693
#        ln_bulk     0.1705     0.1472       1.16     0.2511    -0.1180     0.4591
#      intercept     0.2607     0.9418       0.28     0.7828    -1.5853     2.1067
# ---------------------------------End of Summary---------------------------------

# %%
cleaned_data.plot(x = 'cohesive-energy', y = 'formation-energy', style = 'o')
cleaned_data.plot(x = 'bulk', y = 'formation-energy', style = 'o')
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#cleaned_data.plot(x = 'cohesive-energy', y = 'migration-energy', style = 'o')
cleaned_data.plot(x = 'bulk', y = 'migration-energy', style = 'o')
#cleaned_data[['bulk', 'migration-energy']]

# %%
cleaned_data.loc[:, 'a-1'] = 1.0 / cleaned_data['a']
# Out:
# /opt/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:284: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.py:461: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
plt.plot(cleaned_data['a-1'], cleaned_data['formation-energy'])

# %%
ols(y=cleaned_data['migration-energy'], x=cleaned_data[['bulk', 'cohesive-energy']])
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <bulk> + <cohesive-energy> + <intercept>
#
# Number of Observations:         65
# Number of Degrees of Freedom:   3
#
# R-squared:         0.3006
# Adj R-squared:     0.2780
#
# Rmse:              0.2091
#
# F-stat (2, 62):    13.3221, p-value:     0.0000
#
# Degrees of Freedom: model 2, resid 62
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#           bulk     0.2470     0.0706       3.50     0.0009     0.1086     0.3854
# cohesive-energy     0.0957     0.0273       3.50     0.0009     0.0422     0.1493
#      intercept     0.1861     0.1165       1.60     0.1153    -0.0422     0.4144
# ---------------------------------End of Summary---------------------------------

# %%
ols(y=cleaned_data['migration-energy'], x=cleaned_data[['bulk']])
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <bulk> + <intercept>
#
# Number of Observations:         65
# Number of Degrees of Freedom:   2
#
# R-squared:         0.1622
# Adj R-squared:     0.1489
#
# Rmse:              0.2270
#
# F-stat (1, 63):    12.1991, p-value:     0.0009
#
# Degrees of Freedom: model 1, resid 63
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#           bulk     0.2669     0.0764       3.49     0.0009     0.1171     0.4167
#      intercept     0.5327     0.0666       7.99     0.0000     0.4021     0.6633
# ---------------------------------End of Summary---------------------------------

# %%
ols(y=np.log(cleaned_data['formation-energy'] - 0.2842 * cleaned_data['cohesive-energy']), x=cleaned_data[['ln_bulk', 'ln_relaxation-volume']])
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <ln_bulk> + <ln_relaxation-volume> + <intercept>
#
# Number of Observations:         47
# Number of Degrees of Freedom:   3
#
# R-squared:         0.0872
# Adj R-squared:     0.0457
#
# Rmse:              0.6558
#
# F-stat (2, 44):     2.1012, p-value:     0.1344
#
# Degrees of Freedom: model 2, resid 44
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#        ln_bulk    -0.4760     0.2655      -1.79     0.0798    -0.9963     0.0443
# ln_relaxation-volume    -0.1630     0.1351      -1.21     0.2339    -0.4277     0.1017
#      intercept    -1.2361     0.1674      -7.38     0.0000    -1.5642    -0.9080
# ---------------------------------End of Summary---------------------------------

# %%
cleaned_data.to_csv('cleaned_data.csv')
